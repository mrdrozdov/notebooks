# %%
# %matplotlib notebook

# %%
import numpy as np

import matplotlib.pyplot as plt

# %%
def compute_f1_score(xs, ys, label):
    xlabel, ylabel = xs == label, ys == label
    xtotal, ytotal = xlabel.sum(), ylabel.sum()
    matches = np.logical_and(xs == ys, ylabel)
    correct = matches.sum()
    prec = correct / xtotal
    rec = correct / ytotal
    return 2 * (prec * rec) / (prec + rec), prec, rec

# %%
np.random.seed(11)

n = 1000
points = np.random.randn(n, 2)
y = points[:, 0] > 0
x = np.random.randn(n) > 0

plt.figure()
plt.scatter(points[:, 0][y], points[:, 1][y], color='black')
plt.scatter(points[:, 0][np.logical_not(y)], points[:, 1][np.logical_not(y)], color='gray')
plt.scatter(points[:, 0][x], points[:, 1][x], marker='.', color='white')
plt.show()

print('f1 = {}, precision = {}, recall = {}'.format(*compute_f1_score(x, y, 1)))
# Out:
# <img src="data:image/png;base64,..." width="640">
# f1 = 0.4839357429718876, precision = 0.4908350305498982, recall = 0.4772277227722772

# %%
np.random.seed(11)

n = 1000
points = np.random.randn(n, 2)
y = points[:, 0] > 0
x = points[:, 0] > 0.1

plt.figure()
plt.scatter(points[:, 0][y], points[:, 1][y], color='black')
plt.scatter(points[:, 0][np.logical_not(y)], points[:, 1][np.logical_not(y)], color='gray')
plt.scatter(points[:, 0][x], points[:, 1][x], marker='.', color='white')
plt.show()

print('f1 = {}, precision = {}, recall = {}'.format(*compute_f1_score(x, y, 1)))
# Out:
# <img src="data:image/png;base64,..." width="640">
# f1 = 0.9662231320368476, precision = 1.0, recall = 0.9346534653465347

# %%
np.random.seed(11)

n = 1000
points = np.random.randn(n, 2)
y = points[:, 0] > 0
x = np.logical_and(points[:, 0] > -0.2, points[:, 0] < 0.2)

plt.figure()
plt.scatter(points[:, 0][y], points[:, 1][y], color='black')
plt.scatter(points[:, 0][np.logical_not(y)], points[:, 1][np.logical_not(y)], color='gray')
plt.scatter(points[:, 0][x], points[:, 1][x], marker='.', color='white')
plt.show()

print('f1 = {}, precision = {}, recall = {}'.format(*compute_f1_score(x, y, 1)))
# Out:
# <img src="data:image/png;base64,..." width="640">
# f1 = 0.21296296296296297, precision = 0.4825174825174825, recall = 0.13663366336633664

# %%
np.random.seed(11)

n = 1000
points = np.random.randn(n, 2)
y = points[:, 0] > 0
x = np.logical_and(points[:, 0] > -2, points[:, 0] < 2)

plt.figure()
plt.scatter(points[:, 0][y], points[:, 1][y], color='black')
plt.scatter(points[:, 0][np.logical_not(y)], points[:, 1][np.logical_not(y)], color='gray')
plt.scatter(points[:, 0][x], points[:, 1][x], marker='.', color='white')
plt.show()

print('f1 = {}, precision = {}, recall = {}'.format(*compute_f1_score(x, y, 1)))
# Out:
# <img src="data:image/png;base64,..." width="640">
# f1 = 0.6671261199172984, precision = 0.5116279069767442, recall = 0.9584158415841584
